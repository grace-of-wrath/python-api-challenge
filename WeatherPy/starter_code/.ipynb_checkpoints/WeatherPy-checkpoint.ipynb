# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 611

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = 'http://api.openweathermap.org/data/2.5/weather?'
unit ="metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    #url = "http://api.openweathermap.org/data/2.5/weather?"
    current_city = city
    city_url = url + "appid=" + weather_api_key + "&units=" + unit + "&q=" + current_city
    
    
    #city_url = # YOUR CODE HERE
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | eirunepe
# Processing Record 2 of Set 1 | port-aux-francais
# Processing Record 3 of Set 1 | ilulissat
# Processing Record 4 of Set 1 | wegrow
# Processing Record 5 of Set 1 | poronaysk
# Processing Record 6 of Set 1 | mongagua
# Processing Record 7 of Set 1 | deschutes river woods
# Processing Record 8 of Set 1 | nabire
# Processing Record 9 of Set 1 | tibiri
# Processing Record 10 of Set 1 | ulaangom
# Processing Record 11 of Set 1 | badger
# Processing Record 12 of Set 1 | tromso
# Processing Record 13 of Set 1 | ban na san
# Processing Record 14 of Set 1 | turpan
# Processing Record 15 of Set 1 | rahuri
# Processing Record 16 of Set 1 | la ronge
# Processing Record 17 of Set 1 | al kharijah
# Processing Record 18 of Set 1 | zakamensk
# Processing Record 19 of Set 1 | bethel
# Processing Record 20 of Set 1 | malinyi
# Processing Record 21 of Set 1 | princeville
# Processing Record 22 of Set 1 | kerikeri
# Processing Record 23 of Set 1 | hamilton
# Processing Record 24 of Set 1 | namibe
# Processing Record 25 of Set 1 | paysandu
# Processing Record 26 of Set 1 | yellowknife
# Processing Record 27 of Set 1 | qusmuryn
# Processing Record 28 of Set 1 | bilibino
# Processing Record 29 of Set 1 | grytviken
# Processing Record 30 of Set 1 | iqaluit
# Processing Record 31 of Set 1 | cidreira
# Processing Record 32 of Set 1 | sitka
# Processing Record 33 of Set 1 | papatowai
# Processing Record 34 of Set 1 | avarua
# Processing Record 35 of Set 1 | hell-ville
# Processing Record 36 of Set 1 | bredasdorp
# Processing Record 37 of Set 1 | minas de marcona
# Processing Record 38 of Set 1 | newman
# Processing Record 39 of Set 1 | ushuaia
# Processing Record 40 of Set 1 | jalai nur
# Processing Record 41 of Set 1 | waitangi
# Processing Record 42 of Set 1 | darwin
# Processing Record 43 of Set 1 | qamdo
# Processing Record 44 of Set 1 | adamstown
# Processing Record 45 of Set 1 | utrik
# Processing Record 46 of Set 1 | tiksi
# Processing Record 47 of Set 1 | 'ohonua
# City not found. Skipping...
# Processing Record 48 of Set 1 | blackmans bay
# Processing Record 49 of Set 1 | conduaga
# Processing Record 50 of Set 1 | smithers
# Processing Record 0 of Set 2 | puerto deseado
# Processing Record 1 of Set 2 | smiths station
# Processing Record 2 of Set 2 | tarawa
# Processing Record 3 of Set 2 | kapshagay
# Processing Record 4 of Set 2 | dryden
# Processing Record 5 of Set 2 | constantia
# Processing Record 6 of Set 2 | hengchun
# Processing Record 7 of Set 2 | kuchinda
# Processing Record 8 of Set 2 | haiku-pauwela
# Processing Record 9 of Set 2 | wailua homesteads
# Processing Record 10 of Set 2 | taoudenni
# Processing Record 11 of Set 2 | edinburgh of the seven seas
# Processing Record 12 of Set 2 | thompson
# Processing Record 13 of Set 2 | saint-pierre
# Processing Record 14 of Set 2 | invercargill
# Processing Record 15 of Set 2 | longyearbyen
# Processing Record 16 of Set 2 | art khwajah
# Processing Record 17 of Set 2 | albany
# Processing Record 18 of Set 2 | sierpc
# Processing Record 19 of Set 2 | kapuskasing
# Processing Record 20 of Set 2 | ellsworth
# Processing Record 21 of Set 2 | lae
# Processing Record 22 of Set 2 | kunduz
# Processing Record 23 of Set 2 | carnarvon
# Processing Record 24 of Set 2 | buturlino
# Processing Record 25 of Set 2 | jagna
# Processing Record 26 of Set 2 | ribeira grande
# Processing Record 27 of Set 2 | puerto ayora
# Processing Record 28 of Set 2 | jamestown
# Processing Record 29 of Set 2 | puerto el triunfo
# Processing Record 30 of Set 2 | muisne
# Processing Record 31 of Set 2 | cova figueira
# Processing Record 32 of Set 2 | al artawiyah
# Processing Record 33 of Set 2 | kidal
# Processing Record 34 of Set 2 | anadyr
# Processing Record 35 of Set 2 | saksaul'skiy
# City not found. Skipping...
# Processing Record 36 of Set 2 | afaahiti
# Processing Record 37 of Set 2 | khanty-mansiysk
# Processing Record 38 of Set 2 | siverek
# Processing Record 39 of Set 2 | chinchilla
# Processing Record 40 of Set 2 | puerto natales
# Processing Record 41 of Set 2 | luderitz
# Processing Record 42 of Set 2 | broome
# Processing Record 43 of Set 2 | tralee
# Processing Record 44 of Set 2 | echuca
# Processing Record 45 of Set 2 | uba
# Processing Record 46 of Set 2 | la passe
# Processing Record 47 of Set 2 | kalmunai
# Processing Record 48 of Set 2 | an nuhud
# Processing Record 49 of Set 2 | rio grande
# Processing Record 0 of Set 3 | bom jardim
# Processing Record 1 of Set 3 | chippewa falls
# Processing Record 2 of Set 3 | malakal
# Processing Record 3 of Set 3 | enewetak
# Processing Record 4 of Set 3 | magadan
# Processing Record 5 of Set 3 | port elizabeth
# Processing Record 6 of Set 3 | kabalo
# Processing Record 7 of Set 3 | guiuan
# Processing Record 8 of Set 3 | port mathurin
# Processing Record 9 of Set 3 | antsiranana
# Processing Record 10 of Set 3 | marsh harbour
# Processing Record 11 of Set 3 | yung shue wan
# Processing Record 12 of Set 3 | fortuna
# Processing Record 13 of Set 3 | maralal
# Processing Record 14 of Set 3 | wulingyuan
# Processing Record 15 of Set 3 | tolanaro
# Processing Record 16 of Set 3 | margaret river
# Processing Record 17 of Set 3 | fuli
# Processing Record 18 of Set 3 | inirida
# Processing Record 19 of Set 3 | hermanus
# Processing Record 20 of Set 3 | port lincoln
# Processing Record 21 of Set 3 | susuman
# Processing Record 22 of Set 3 | west island
# Processing Record 23 of Set 3 | happy valley-goose bay
# Processing Record 24 of Set 3 | somanda
# Processing Record 25 of Set 3 | idri
# Processing Record 26 of Set 3 | caleta de carquin
# Processing Record 27 of Set 3 | hilo
# Processing Record 28 of Set 3 | college
# Processing Record 29 of Set 3 | karratha
# Processing Record 30 of Set 3 | muravlenko
# Processing Record 31 of Set 3 | praia da vitoria
# Processing Record 32 of Set 3 | maragogi
# Processing Record 33 of Set 3 | bikenibeu village
# Processing Record 34 of Set 3 | whitehorse
# Processing Record 35 of Set 3 | thunder bay
# Processing Record 36 of Set 3 | les cayes
# Processing Record 37 of Set 3 | siocon
# Processing Record 38 of Set 3 | severobaykal'sk
# Processing Record 39 of Set 3 | st. john's
# Processing Record 40 of Set 3 | zhangatas
# Processing Record 41 of Set 3 | shaowu
# Processing Record 42 of Set 3 | kodiak
# Processing Record 43 of Set 3 | polyarnyy
# Processing Record 44 of Set 3 | boende
# Processing Record 45 of Set 3 | pisco
# Processing Record 46 of Set 3 | codrington
# Processing Record 47 of Set 3 | chibuto
# Processing Record 48 of Set 3 | new norfolk
# Processing Record 49 of Set 3 | agaie
# Processing Record 0 of Set 4 | ulsteinvik
# Processing Record 1 of Set 4 | borodinskiy
# Processing Record 2 of Set 4 | hualien city
# Processing Record 3 of Set 4 | kaitong
# Processing Record 4 of Set 4 | onega
# Processing Record 5 of Set 4 | trapani
# Processing Record 6 of Set 4 | santa ana
# Processing Record 7 of Set 4 | vila franca do campo
# Processing Record 8 of Set 4 | cestos city
# Processing Record 9 of Set 4 | urucui
# Processing Record 10 of Set 4 | gopalpur
# Processing Record 11 of Set 4 | shadegan
# Processing Record 12 of Set 4 | kultali
# City not found. Skipping...
# Processing Record 13 of Set 4 | bardsir
# Processing Record 14 of Set 4 | aasiaat
# Processing Record 15 of Set 4 | port macquarie
# Processing Record 16 of Set 4 | tuni
# Processing Record 17 of Set 4 | saipan
# Processing Record 18 of Set 4 | tranovaho
# City not found. Skipping...
# Processing Record 19 of Set 4 | rada tilly
# Processing Record 20 of Set 4 | pokhara
# Processing Record 21 of Set 4 | lexington
# Processing Record 22 of Set 4 | georgetown
# Processing Record 23 of Set 4 | east london
# Processing Record 24 of Set 4 | arinos
# Processing Record 25 of Set 4 | tazovsky
# Processing Record 26 of Set 4 | ancud
# Processing Record 27 of Set 4 | imbituba
# Processing Record 28 of Set 4 | hayma'
# City not found. Skipping...
# Processing Record 29 of Set 4 | isafjordur
# Processing Record 30 of Set 4 | kavaratti
# Processing Record 31 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 32 of Set 4 | mitu
# Processing Record 33 of Set 4 | owo
# Processing Record 34 of Set 4 | saddiqabad
# Processing Record 35 of Set 4 | tionk essil
# Processing Record 36 of Set 4 | wynyard
# Processing Record 37 of Set 4 | howrah
# Processing Record 38 of Set 4 | 'alaqahdari dishu
# Processing Record 39 of Set 4 | zilupe
# Processing Record 40 of Set 4 | klyuchi
# Processing Record 41 of Set 4 | hirara
# Processing Record 42 of Set 4 | borkum
# Processing Record 43 of Set 4 | fale old settlement
# Processing Record 44 of Set 4 | geraldton
# Processing Record 45 of Set 4 | ouarzazat
# Processing Record 46 of Set 4 | weno
# Processing Record 47 of Set 4 | kayangel
# Processing Record 48 of Set 4 | stanley
# Processing Record 49 of Set 4 | bardai
# Processing Record 0 of Set 5 | cable beach
# City not found. Skipping...
# Processing Record 1 of Set 5 | whittlesea
# Processing Record 2 of Set 5 | novo aripuana
# Processing Record 3 of Set 5 | chui
# Processing Record 4 of Set 5 | hadibu
# Processing Record 5 of Set 5 | vingt cinq
# City not found. Skipping...
# Processing Record 6 of Set 5 | tidjikja
# Processing Record 7 of Set 5 | okha
# Processing Record 8 of Set 5 | komsomol'skiy
# Processing Record 9 of Set 5 | conde
# Processing Record 10 of Set 5 | ust-nera
# Processing Record 11 of Set 5 | nova sintra
# Processing Record 12 of Set 5 | zouerate
# Processing Record 13 of Set 5 | shingu
# Processing Record 14 of Set 5 | takanabe
# Processing Record 15 of Set 5 | port blair
# Processing Record 16 of Set 5 | arraias
# Processing Record 17 of Set 5 | san nicolas
# Processing Record 18 of Set 5 | thames
# Processing Record 19 of Set 5 | funafuti
# Processing Record 20 of Set 5 | sukhobezvodnoye
# Processing Record 21 of Set 5 | hawaiian paradise park
# Processing Record 22 of Set 5 | nizhniy kuranakh
# Processing Record 23 of Set 5 | usogorsk
# Processing Record 24 of Set 5 | rongelap
# Processing Record 25 of Set 5 | hithadhoo
# Processing Record 26 of Set 5 | amod
# Processing Record 27 of Set 5 | qaqortoq
# Processing Record 28 of Set 5 | acarau
# Processing Record 29 of Set 5 | olonkinbyen
# Processing Record 30 of Set 5 | cabo san lucas
# Processing Record 31 of Set 5 | paita
# Processing Record 32 of Set 5 | muzayri'
# City not found. Skipping...
# Processing Record 33 of Set 5 | chimbote
# Processing Record 34 of Set 5 | kenai
# Processing Record 35 of Set 5 | preobrazheniye
# Processing Record 36 of Set 5 | mirpur sakro
# Processing Record 37 of Set 5 | port alfred
# Processing Record 38 of Set 5 | mount pearl
# Processing Record 39 of Set 5 | saurimo
# Processing Record 40 of Set 5 | taiohae
# City not found. Skipping...
# Processing Record 41 of Set 5 | toga village
# City not found. Skipping...
# Processing Record 42 of Set 5 | vernon
# Processing Record 43 of Set 5 | michalovce
# Processing Record 44 of Set 5 | eyl
# Processing Record 45 of Set 5 | tamandare
# Processing Record 46 of Set 5 | tumayr
# Processing Record 47 of Set 5 | wagar
# Processing Record 48 of Set 5 | nakodar
# Processing Record 49 of Set 5 | ballina
# Processing Record 0 of Set 6 | prado del rey
# Processing Record 1 of Set 6 | haimen
# Processing Record 2 of Set 6 | tura
# Processing Record 3 of Set 6 | lihue
# Processing Record 4 of Set 6 | vilyuysk
# Processing Record 5 of Set 6 | summerside
# Processing Record 6 of Set 6 | i-n-salah
# Processing Record 7 of Set 6 | houlton
# Processing Record 8 of Set 6 | mount gambier
# Processing Record 9 of Set 6 | dudinka
# Processing Record 10 of Set 6 | talnakh
# Processing Record 11 of Set 6 | vila velha
# Processing Record 12 of Set 6 | srandakan
# Processing Record 13 of Set 6 | nurota
# Processing Record 14 of Set 6 | howard springs
# Processing Record 15 of Set 6 | vernal
# Processing Record 16 of Set 6 | sengkang
# Processing Record 17 of Set 6 | bela
# Processing Record 18 of Set 6 | swan hill
# Processing Record 19 of Set 6 | saynshand
# Processing Record 20 of Set 6 | flying fish cove
# Processing Record 21 of Set 6 | formosa
# Processing Record 22 of Set 6 | hammerfest
# Processing Record 23 of Set 6 | punta arenas
# Processing Record 24 of Set 6 | callao
# Processing Record 25 of Set 6 | el calafate
# Processing Record 26 of Set 6 | kodinsk
# Processing Record 27 of Set 6 | mount isa
# Processing Record 28 of Set 6 | sao joao do paraiso
# Processing Record 29 of Set 6 | yuzawa
# Processing Record 30 of Set 6 | labrador city
# Processing Record 31 of Set 6 | golpayegan
# Processing Record 32 of Set 6 | san patricio
# Processing Record 33 of Set 6 | saint-denis
# Processing Record 34 of Set 6 | kingston
# Processing Record 35 of Set 6 | dompu
# Processing Record 36 of Set 6 | fall river
# Processing Record 37 of Set 6 | saint-francois
# Processing Record 38 of Set 6 | ladismith
# City not found. Skipping...
# Processing Record 39 of Set 6 | barra de santo antonio
# Processing Record 40 of Set 6 | kununurra
# Processing Record 41 of Set 6 | padang
# Processing Record 42 of Set 6 | brookings
# Processing Record 43 of Set 6 | touros
# Processing Record 44 of Set 6 | kuhmo
# Processing Record 45 of Set 6 | crane
# Processing Record 46 of Set 6 | snyder
# Processing Record 47 of Set 6 | alofi
# Processing Record 48 of Set 6 | buka
# Processing Record 49 of Set 6 | slave lake
# Processing Record 0 of Set 7 | labuan
# Processing Record 1 of Set 7 | cheonan
# Processing Record 2 of Set 7 | guaratinga
# Processing Record 3 of Set 7 | keflavik
# Processing Record 4 of Set 7 | ghazni
# Processing Record 5 of Set 7 | atafu village
# Processing Record 6 of Set 7 | muborak
# Processing Record 7 of Set 7 | bayan nur
# City not found. Skipping...
# Processing Record 8 of Set 7 | al ghayzah
# Processing Record 9 of Set 7 | lebu
# Processing Record 10 of Set 7 | berdigestyakh
# Processing Record 11 of Set 7 | olean
# Processing Record 12 of Set 7 | duyun
# Processing Record 13 of Set 7 | sydney
# Processing Record 14 of Set 7 | diamantino
# Processing Record 15 of Set 7 | ulladulla
# Processing Record 16 of Set 7 | afyonkarahisar
# Processing Record 17 of Set 7 | zyryanskoye
# Processing Record 18 of Set 7 | saint-philippe
# Processing Record 19 of Set 7 | kuala lipis
# Processing Record 20 of Set 7 | udachny
# Processing Record 21 of Set 7 | whyalla stuart
# City not found. Skipping...
# Processing Record 22 of Set 7 | baissa
# Processing Record 23 of Set 7 | eraan
# Processing Record 24 of Set 7 | goderich
# Processing Record 25 of Set 7 | punta cardon
# Processing Record 26 of Set 7 | sendafa
# Processing Record 27 of Set 7 | tarfaya
# Processing Record 28 of Set 7 | dunaujvaros
# Processing Record 29 of Set 7 | cargados carajos
# City not found. Skipping...
# Processing Record 30 of Set 7 | tovarkovo
# Processing Record 31 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 32 of Set 7 | tshikapa
# Processing Record 33 of Set 7 | hillview
# Processing Record 34 of Set 7 | kuqa
# Processing Record 35 of Set 7 | fyodorovka
# Processing Record 36 of Set 7 | nishinoomote
# Processing Record 37 of Set 7 | juneau
# Processing Record 38 of Set 7 | coxim
# Processing Record 39 of Set 7 | holualoa
# Processing Record 40 of Set 7 | uturoa
# Processing Record 41 of Set 7 | savalou
# Processing Record 42 of Set 7 | vadso
# Processing Record 43 of Set 7 | kolyshley
# Processing Record 44 of Set 7 | chonchi
# Processing Record 45 of Set 7 | vorgashor
# Processing Record 46 of Set 7 | fort st. john
# Processing Record 47 of Set 7 | ceeldheer
# Processing Record 48 of Set 7 | hassi messaoud
# Processing Record 49 of Set 7 | berezovo
# Processing Record 0 of Set 8 | severo-yeniseyskiy
# Processing Record 1 of Set 8 | idabel
# Processing Record 2 of Set 8 | cururupu
# Processing Record 3 of Set 8 | saudarkrokur
# Processing Record 4 of Set 8 | khandyga
# Processing Record 5 of Set 8 | asau
# Processing Record 6 of Set 8 | richards bay
# Processing Record 7 of Set 8 | tsiombe
# Processing Record 8 of Set 8 | kalispell
# Processing Record 9 of Set 8 | arteche
# Processing Record 10 of Set 8 | bratsk
# Processing Record 11 of Set 8 | rozhyshche
# Processing Record 12 of Set 8 | contai
# Processing Record 13 of Set 8 | bonthe
# Processing Record 14 of Set 8 | lycksele
# Processing Record 15 of Set 8 | sur
# Processing Record 16 of Set 8 | zyrya
# Processing Record 17 of Set 8 | colonia
# Processing Record 18 of Set 8 | zaozersk
# Processing Record 19 of Set 8 | gaiman
# Processing Record 20 of Set 8 | nova vicosa
# Processing Record 21 of Set 8 | bodo
# Processing Record 22 of Set 8 | verkhnevilyuysk
# Processing Record 23 of Set 8 | guerrero negro
# Processing Record 24 of Set 8 | bandrele
# Processing Record 25 of Set 8 | san luis de la loma
# Processing Record 26 of Set 8 | marquette
# Processing Record 27 of Set 8 | leava
# Processing Record 28 of Set 8 | olavarria
# Processing Record 29 of Set 8 | coquimbo
# Processing Record 30 of Set 8 | port saint john's
# Processing Record 31 of Set 8 | banff
# Processing Record 32 of Set 8 | sandnessjoen
# Processing Record 33 of Set 8 | chubbuck
# Processing Record 34 of Set 8 | ahau
# City not found. Skipping...
# Processing Record 35 of Set 8 | novi sad
# Processing Record 36 of Set 8 | vilyuchinsk
# Processing Record 37 of Set 8 | san andres
# Processing Record 38 of Set 8 | copala
# Processing Record 39 of Set 8 | kailua-kona
# Processing Record 40 of Set 8 | taulaga
# Processing Record 41 of Set 8 | salinas
# Processing Record 42 of Set 8 | robit
# Processing Record 43 of Set 8 | iskateley
# Processing Record 44 of Set 8 | westport
# Processing Record 45 of Set 8 | moyynkum
# Processing Record 46 of Set 8 | arar
# Processing Record 47 of Set 8 | tekkali
# Processing Record 48 of Set 8 | puerto san carlos
# City not found. Skipping...
# Processing Record 49 of Set 8 | swakopmund
# Processing Record 0 of Set 9 | angul
# Processing Record 1 of Set 9 | divnoye
# Processing Record 2 of Set 9 | labytnangi
# Processing Record 3 of Set 9 | glen innes
# Processing Record 4 of Set 9 | trashigang
# Processing Record 5 of Set 9 | xiongzhou
# Processing Record 6 of Set 9 | goure
# Processing Record 7 of Set 9 | barcelos
# Processing Record 8 of Set 9 | al mijlad
# Processing Record 9 of Set 9 | santiago de cao
# Processing Record 10 of Set 9 | concepcion del oro
# Processing Record 11 of Set 9 | whakatane
# Processing Record 12 of Set 9 | tongchuanshi
# Processing Record 13 of Set 9 | nueva concepcion
# Processing Record 14 of Set 9 | vorkuta
# Processing Record 15 of Set 9 | thurso
# Processing Record 16 of Set 9 | bubaque
# Processing Record 17 of Set 9 | kuusamo
# Processing Record 18 of Set 9 | fuvahmulah
# City not found. Skipping...
# Processing Record 19 of Set 9 | seven pagodas
# Processing Record 20 of Set 9 | dunedin
# Processing Record 21 of Set 9 | kegen
# Processing Record 22 of Set 9 | banfora
# Processing Record 23 of Set 9 | gamba
# Processing Record 24 of Set 9 | alice springs
# Processing Record 25 of Set 9 | port said
# Processing Record 26 of Set 9 | etawa
# Processing Record 27 of Set 9 | bhadra
# Processing Record 28 of Set 9 | alva
# Processing Record 29 of Set 9 | hasaki
# Processing Record 30 of Set 9 | navirai
# Processing Record 31 of Set 9 | la'ie
# Processing Record 32 of Set 9 | schramberg
# Processing Record 33 of Set 9 | mawu
# Processing Record 34 of Set 9 | den burg
# Processing Record 35 of Set 9 | korla
# Processing Record 36 of Set 9 | kokofata
# City not found. Skipping...
# Processing Record 37 of Set 9 | laojunmiao
# Processing Record 38 of Set 9 | yermakovskoye
# Processing Record 39 of Set 9 | haag in oberbayern
# Processing Record 40 of Set 9 | rio negrinho
# Processing Record 41 of Set 9 | porto torres
# Processing Record 42 of Set 9 | kendari
# Processing Record 43 of Set 9 | sinabang
# Processing Record 44 of Set 9 | kokopo
# Processing Record 45 of Set 9 | chimoio
# Processing Record 46 of Set 9 | kone
# Processing Record 47 of Set 9 | baise city
# Processing Record 48 of Set 9 | sortavala
# Processing Record 49 of Set 9 | lagunas
# Processing Record 0 of Set 10 | likiep
# Processing Record 1 of Set 10 | marsa alam
# Processing Record 2 of Set 10 | essaouira
# Processing Record 3 of Set 10 | khash
# Processing Record 4 of Set 10 | xinyang
# Processing Record 5 of Set 10 | city of balikpapan
# Processing Record 6 of Set 10 | rio gallegos
# Processing Record 7 of Set 10 | sisimiut
# Processing Record 8 of Set 10 | hinton
# Processing Record 9 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 10 of Set 10 | dhidhdhoo
# Processing Record 11 of Set 10 | alesund
# Processing Record 12 of Set 10 | livada
# Processing Record 13 of Set 10 | pingnan
# Processing Record 14 of Set 10 | baranivka
# Processing Record 15 of Set 10 | muang phonsavan
# Processing Record 16 of Set 10 | road town
# Processing Record 17 of Set 10 | gamay
# Processing Record 18 of Set 10 | mantua
# Processing Record 19 of Set 10 | yelizovo
# Processing Record 20 of Set 10 | gunnedah
# Processing Record 21 of Set 10 | nuevo progreso
# Processing Record 22 of Set 10 | palmer
# Processing Record 23 of Set 10 | yaren
# Processing Record 24 of Set 10 | kyshtovka
# Processing Record 25 of Set 10 | dezhou
# Processing Record 26 of Set 10 | mabaruma
# Processing Record 27 of Set 10 | ingeniero luis a. huergo
# Processing Record 28 of Set 10 | malvan
# Processing Record 29 of Set 10 | askoy
# Processing Record 30 of Set 10 | yagry
# City not found. Skipping...
# Processing Record 31 of Set 10 | anton lizardo
# Processing Record 32 of Set 10 | george town
# Processing Record 33 of Set 10 | santa isabel
# Processing Record 34 of Set 10 | urangan
# Processing Record 35 of Set 10 | rocky mountain house
# Processing Record 36 of Set 10 | levuka
# Processing Record 37 of Set 10 | cooma
# Processing Record 38 of Set 10 | mossel bay
# Processing Record 39 of Set 10 | soio
# Processing Record 40 of Set 10 | urengoy
# Processing Record 41 of Set 10 | san felipe
# Processing Record 42 of Set 10 | tual
# Processing Record 43 of Set 10 | al hawatah
# Processing Record 44 of Set 10 | luena
# Processing Record 45 of Set 10 | beyneu
# Processing Record 46 of Set 10 | the pas
# Processing Record 47 of Set 10 | lata
# Processing Record 48 of Set 10 | nouadhibou
# Processing Record 49 of Set 10 | lerwick
# Processing Record 0 of Set 11 | cuatro cienegas de carranza
# Processing Record 1 of Set 11 | inhambane
# Processing Record 2 of Set 11 | kolwezi
# Processing Record 3 of Set 11 | balkh
# Processing Record 4 of Set 11 | zdvinsk
# Processing Record 5 of Set 11 | roxboro
# Processing Record 6 of Set 11 | mubende
# Processing Record 7 of Set 11 | quellon
# Processing Record 8 of Set 11 | behompy
# Processing Record 9 of Set 11 | queenstown
# Processing Record 10 of Set 11 | barakani
# Processing Record 11 of Set 11 | aliaga
# Processing Record 12 of Set 11 | awjilah
# Processing Record 13 of Set 11 | kourou
# Processing Record 14 of Set 11 | antalaha
# Processing Record 15 of Set 11 | upper grand lagoon
# Processing Record 16 of Set 11 | tanout
# Processing Record 17 of Set 11 | kulia village
# City not found. Skipping...
# Processing Record 18 of Set 11 | laguna de perlas
# Processing Record 19 of Set 11 | williston
# Processing Record 20 of Set 11 | kolonia
# Processing Record 21 of Set 11 | novi pazar
# Processing Record 22 of Set 11 | altai
# Processing Record 23 of Set 11 | katsuren-haebaru
# Processing Record 24 of Set 11 | kirakira
# Processing Record 25 of Set 11 | marka
# Processing Record 26 of Set 11 | mahenge
# Processing Record 27 of Set 11 | grand falls-windsor
# Processing Record 28 of Set 11 | imeni morozova
# Processing Record 29 of Set 11 | pitimbu
# Processing Record 30 of Set 11 | annau
# Processing Record 31 of Set 11 | sokoni
# Processing Record 32 of Set 11 | zaragoza
# Processing Record 33 of Set 11 | abepura
# Processing Record 34 of Set 11 | midvagur
# Processing Record 35 of Set 11 | arkhangel'sk
# Processing Record 36 of Set 11 | kalemie
# Processing Record 37 of Set 11 | oodweyne
# Processing Record 38 of Set 11 | bejubang dua
# City not found. Skipping...
# Processing Record 39 of Set 11 | rawa mazowiecka
# Processing Record 40 of Set 11 | saint-marc
# Processing Record 41 of Set 11 | jayapura
# Processing Record 42 of Set 11 | katabu
# Processing Record 43 of Set 11 | canutama
# Processing Record 44 of Set 11 | arno
# Processing Record 45 of Set 11 | sao felix do xingu
# Processing Record 46 of Set 11 | puerto baquerizo moreno
# Processing Record 47 of Set 11 | kahna nau
# Processing Record 48 of Set 11 | pathein
# Processing Record 49 of Set 11 | sabang
# Processing Record 0 of Set 12 | fereydunshahr
# Processing Record 1 of Set 12 | bel ombre
# Processing Record 2 of Set 12 | kogalym
# Processing Record 3 of Set 12 | sao jose dos campos
# Processing Record 4 of Set 12 | rovaniemi
# Processing Record 5 of Set 12 | itoman
# Processing Record 6 of Set 12 | nemuro
# Processing Record 7 of Set 12 | pingyi
# Processing Record 8 of Set 12 | oamaru
# Processing Record 9 of Set 12 | shimoda
# Processing Record 10 of Set 12 | sishilichengzi
# City not found. Skipping...
# Processing Record 11 of Set 12 | brisas barra de suchiate
# Processing Record 12 of Set 12 | pacific grove
# Processing Record 13 of Set 12 | puerto armuelles
# Processing Record 14 of Set 12 | nizhniy odes
# Processing Record 15 of Set 12 | bathsheba
# Processing Record 16 of Set 12 | tazacorte
# Processing Record 17 of Set 12 | fort bragg
# Processing Record 18 of Set 12 | papao
# Processing Record 19 of Set 12 | kruisfontein
# Processing Record 20 of Set 12 | lompoc
# Processing Record 21 of Set 12 | jilib
# Processing Record 22 of Set 12 | nadym
# Processing Record 23 of Set 12 | 'ibri
# City not found. Skipping...
# Processing Record 24 of Set 12 | seferihisar
# Processing Record 25 of Set 12 | yurga
# Processing Record 26 of Set 12 | xuddur
# Processing Record 27 of Set 12 | hotan
# Processing Record 28 of Set 12 | odienne
# Processing Record 29 of Set 12 | binzhou
# Processing Record 30 of Set 12 | tanjungtiram
# Processing Record 31 of Set 12 | nadi
# Processing Record 32 of Set 12 | lamar
# Processing Record 33 of Set 12 | yuzhno-kurilsk
# Processing Record 34 of Set 12 | kill devil hills
# Processing Record 35 of Set 12 | tanjung pandan
# Processing Record 36 of Set 12 | bani walid
# Processing Record 37 of Set 12 | aswan
# Processing Record 38 of Set 12 | fisterra
# Processing Record 39 of Set 12 | sola
# Processing Record 40 of Set 12 | pemba
# Processing Record 41 of Set 12 | harper
# Processing Record 42 of Set 12 | zhigalovo
# Processing Record 43 of Set 12 | coyutla
# Processing Record 44 of Set 12 | medina
# Processing Record 45 of Set 12 | valparaiso
# Processing Record 46 of Set 12 | borba
# Processing Record 47 of Set 12 | horta
# Processing Record 48 of Set 12 | chibougamau
# Processing Record 49 of Set 12 | dhi as sufal
# Processing Record 0 of Set 13 | 'ain el turk
# Processing Record 1 of Set 13 | orchard homes
# Processing Record 2 of Set 13 | tarancon
# Processing Record 3 of Set 13 | panaba
# Processing Record 4 of Set 13 | lysianka
# Processing Record 5 of Set 13 | pariaman
# Processing Record 6 of Set 13 | wotho
# Processing Record 7 of Set 13 | bom jesus
# Processing Record 8 of Set 13 | potam
# Processing Record 9 of Set 13 | vilhena
# Processing Record 10 of Set 13 | dom pedrito
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
unit = "metric"
phoenix_url = url + "appid=" + weather_api_key + "&units=" + unit + "&q=" + 'london'
phoenix_weather = requests.get(city_url).json()
print(phoenix_weather)
# Out:
# {'coord': {'lon': -54.6731, 'lat': -30.9828}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 5.49, 'feels_like': 1.89, 'temp_min': 5.49, 'temp_max': 5.49, 'pressure': 1020, 'humidity': 94, 'sea_level': 1020, 'grnd_level': 1002}, 'visibility': 10000, 'wind': {'speed': 5.13, 'deg': 169, 'gust': 11.21}, 'clouds': {'all': 88}, 'dt': 1697094670, 'sys': {'country': 'BR', 'sunrise': 1697101406, 'sunset': 1697147204}, 'timezone': -10800, 'id': 3464547, 'name': 'Dom Pedrito', 'cod': 200}

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          586
# Lat           586
# Lng           586
# Max Temp      586
# Humidity      586
# Cloudiness    586
# Wind Speed    586
# Country       586
# Date          586
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           eirunepe  -6.6603  -69.8736     24.02        84          71
# 1  port-aux-francais -49.3500   70.2167      1.69       100         100
# 2          ilulissat  69.2167  -51.1000     -2.99        74          75
# 3             wegrow  52.3995   22.0163     18.27        60         100
# 4          poronaysk  49.2167  143.1167     14.05        46           7
#
#    Wind Speed Country        Date
# 0        1.16      BR  1697094617
# 1        6.77      TF  1697094617
# 2        7.72      GL  1697094617
# 3        7.87      PL  1697094617
# 4        4.37      RU  1697094553

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")
# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                 eirunepe  -6.6603  -69.8736     24.02        84          71
# 1        port-aux-francais -49.3500   70.2167      1.69       100         100
# 2                ilulissat  69.2167  -51.1000     -2.99        74          75
# 3                   wegrow  52.3995   22.0163     18.27        60         100
# 4                poronaysk  49.2167  143.1167     14.05        46           7
#
#          Wind Speed Country        Date
# City_ID
# 0              1.16      BR  1697094617
# 1              6.77      TF  1697094617
# 2              7.72      GL  1697094617
# 3              7.87      PL  1697094617
# 4              4.37      RU  1697094553

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
today = datetime.now().date()

x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature(C)')
plt.title(f'City Latitude vs. Max Temperature {today}')
# Incorporate the other graph properties
plt.grid()
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_values = city_data_df['Lat']
y_values = city_data_df['Humidity']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
plt.title(f'City Latitude vs. Humidity {today}')

# Incorporate the other graph properties
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values = city_data_df['Lat']
y_values = city_data_df['Cloudiness']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f'City Latitude vs. Cloudiness {today}')

# Incorporate the other graph properties
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_values = city_data_df['Lat']
y_values = city_data_df['Wind Speed']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title(f'City Latitude vs. Wind Speed {today}')

# Incorporate the other graph properties
plt.grid()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                           City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 2                    ilulissat  69.2167  -51.1000     -2.99        74
# 3                       wegrow  52.3995   22.0163     18.27        60
# 4                    poronaysk  49.2167  143.1167     14.05        46
# 6        deschutes river woods  43.9915 -121.3584      6.77        82
# 8                       tibiri  13.5627    7.0485     29.75        27
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 2                75        7.72      GL  1697094617
# 3               100        7.87      PL  1697094617
# 4                 7        4.37      RU  1697094553
# 6                40        0.00      US  1697094618
# 8                91        3.84      NE  1697094619

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                 eirunepe  -6.6603  -69.8736     24.02        84          71
# 1        port-aux-francais -49.3500   70.2167      1.69       100         100
# 5                 mongagua -24.0931  -46.6208     23.14        88         100
# 7                   nabire  -3.3667  135.4833     29.01        71         100
# 19                 malinyi  -8.9333   36.1333     31.36        38          20
#
#          Wind Speed Country        Date
# City_ID
# 0              1.16      BR  1697094617
# 1              6.77      TF  1697094617
# 5              4.67      BR  1697094342
# 7              1.83      ID  1697094567
# 19             0.69      TZ  1697094556

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.annotate(line_eq,(10,-8),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.7399849408346346

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.annotate(line_eq,(-30,0),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.5706912177115376

# %% [markdown]
# **Discussion about the linear relationship:** Looking at the linear regression we plotted, we can see that the relationship between max temp and latitude is nearly inverse, in regards to the Northern and Southern hemispheres. The Northern Hemisphere shows a moderate negative correlation between temperature and latitude, meaning as latitude rises, temperatures decrease. Conversely, the Southern Hemisphere has the opposite relationship, wherein temperatures rises as latitude rises.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.annotate(line_eq,(50,20),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.018078328341994444

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.annotate(line_eq,(-50,40),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.002072914797609013

# %% [markdown]
# **Discussion about the linear relationship:** In both graphs, we see close to zero correlation between humidity, however, it is noteworthy that humidity and temperature are slightly positively correlated in the Northern Hemisphere, and slightly negatively correlated in the Southern Hemisphere. Neither can be considered signifcant though.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.annotate(line_eq,(50,20),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.025130198321810914

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.annotate(line_eq,(-45,25),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.005528602182130449

# %% [markdown]
# **Discussion about the linear relationship:** Again, there is little relationship between Cloudiness and Latitude. In both the Northern and Southern hemispheres, we see a very slight positive correlation, however, the value is close to zero.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.annotate(line_eq,(10,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.057623054847210156

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, "r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.annotate(line_eq,(-55,9),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.12462884732910862

# %% [markdown]
# **Discussion about the linear relationship:** Wind speed is also lowly correlated to latitude. In the Northern Hemisphere we see a slightly positive correlation, while in the Southern there is a slightly negative. Interestingly, clusters in both scatter plots intimate a stronger correlation than what actually exists.
